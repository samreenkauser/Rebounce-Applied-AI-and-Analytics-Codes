# %% [markdown]
# <a href="https://colab.research.google.com/github/samreenkauser/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 1. The Introduction Card**

# %%
name       = "Samreen"
city       = "Patna"
birth_year = 2004
age        = 2026 - birth_year

print(f"""Hi, I'm {name} from {city}.
This year I turn {age}""")
# Out:
# Hi, I'm Samreen from Patna.
# This year I turn 22

# %% [markdown]
# **Problem 2. The Currency** **Exchange**

# %%
amount        = 75000
exchange_rate = 1.75 # 1 rupee = 1.75 yen
final_amount  = amount * exchange_rate

print ("final amount:",f"{final_amount:.2f}")
# Out:
# final amount: 131250.00

# %% [markdown]
# **Problem 3. The Grocery Bill**

# %%
bread = 40
milk  = 65.50
eggs  = 120
total = bread + milk + eggs
average_price_per_item = total / 3

print("Total:",f"{total:.2f}")
print("Average per item:",f"{average_price_per_item:.2f}")
# Out:
# Total: 225.50
# Average per item: 75.17

# %% [markdown]
# **Problem 4. Odd or Even?**

# %%
number = 59
is_even = number % 2 == 0

print(f"Is",number,"even?", is_even)
# Out:
# Is 59 even? False

# %%
number = 92
is_even = number % 2 == 0

print(f"Is",number,"even?", is_even)
# Out:
# Is 92 even? True

# %% [markdown]
# **Problem 5. The Password Strenght Check**

# %%
password = "PYT LIK"
length   = len(password) # Fixed typo: lenght -> length
length_greater_than_8 = length >= 8
contains_at = "@" in password # Fixed logic: check if '@' is in password
is_it_strong = length_greater_than_8 and contains_at # Fixed typo: stong -> strong, and used correct length variable
print("Is it strong?", is_it_strong) # Fixed SyntaxError by removing '9' and typo 'srong'
# Out:
# Is it strong? False
