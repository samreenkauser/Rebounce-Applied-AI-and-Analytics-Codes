# %% [markdown]
# <a href="https://colab.research.google.com/github/samreenkauser/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(11))
print(type(21.213))
print(type("Hello"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(type(1))
print(type(1.0))
# Are they equal in VALUE? Use the compaison operator.
print(1==1.0)
# Out:
# <class 'int'>
# <class 'float'>
# True

# %%
print(float(2))
print(int(3.99))
print(int(5))
print(str("42"))
print(int(False))
# Out:
# 2.0
# 3
# 5
# 42
# 0

# %%
value = 4.7

print(int(value))
print(round(4.7))
# Out:
# 4
# 5

# %%
a = 17
b = 5

print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 3.4
# 3
# 2
# 1419857

# %%
# Currently this prints 150 because * happens before +.
print((30 + 2) * 60)

# Now make this line print 1920.
print(150)
# Out:
# 1920
# 150

# %%
song_1 = 43
song_2 = 42
song_3 = 57

total_minutes = song_1 + song_2 + song_3
total_hours = total_minutes / 60

print("Total minutes:" , total_minutes)
print("Total hours:" , total_hours)
# Out:
# Total minutes: 142
# Total hours: 2.3666666666666667

# %%
album_year = 1982
print(album_year>= 1980 and album_year <= 1982)

album_year = 1991
print(album_year>= 1980 and album_year <= 1989)
# Out:
# True
# False

# %%
print(True and True)
print(True or True)
print(not False)
print(5 > 3) or (2 > 9)
# Out:
# True
# True
# True
# True
# False

# %%
# print("5" + 5)
# print(int("hello"))
# print(10 / 0)
# print(undefined_variables)

# Which error did each one give?
# 1. TypeError
# 2. ValueError
# 3. ZeroDivisionError
# 4. NameError

# %%
tea_price = 10
coffee_price = 25

tea_quantity = 3
coffee_quantity = 2

subtotal = tea_price * tea_quantity + coffee_price * coffee_quantity
gst = subtotal * 0.05
total = subtotal + gst

print (total)
print(subtotal)
# Out:
# 84.0
# 80
